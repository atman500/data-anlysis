# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
data= pd.read_csv("file1.csv",sep=";")

# %%
print(data.head())
# Out:
#       YER     PCR       GCR       ITR     XTR       MTR
# 0  741676  410926  130752.3  191804.9  102120  105319.5
# 1  755933  416040  133067.5  203195.4  104740  107939.4
# 2  765040  421031  134996.7  206286.9  107148  111606.1
# 3  774307  429207  137219.5  205445.2  108605  111909.4
# 4  772953  432162  137677.4  204343.4  110814  113755.4

# %%
YER=data['YER']

# %%
print(YER.head())
# Out:
# 0    741676
# 1    755933
# 2    765040
# 3    774307
# 4    772953
# Name: YER, dtype: int64

# %%
import numpy as np

# %%
print(YER.std)
# Out:
# <bound method Series.std of 0       741676
# 1       755933
# 2       765040
# 3       774307
# 4       772953
#         ...
# 183    1924837
# 184    1934990
# 185    1941665
# 186    1949490
# 187    1961140
# Name: YER, Length: 188, dtype: int64>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(YER)
